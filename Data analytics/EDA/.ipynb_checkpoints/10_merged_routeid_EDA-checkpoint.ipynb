# %% [markdown]
# ## ANALYSIS: IMPORTANT ROUTEIDS
# **THIS NOTEBOOK ANALYSES JAN_TRIPS_MERGED.CSV; DROPS UNNECESSARY ROUTEIDS AND GENERATES imp_ROUTEID_Jan_trips_MERGED.csv**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages


from warnings import filterwarnings
filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Source of Truth
# ### Source of Truth gathered in prior EDA
# * **TRIPID**
#     * **TRIPID are shared across days for perticular LINEID on particular ROUTEID**
#     * For a single TRIPID, only one corresponding LINEID and ROUTEID are present
#     * TRIPID for inbound and outbound directions are mutually exclusive
#     * For certein TRIPIDs; PROGNUMBER do not start at 1; which should. It means, some entries are missing.
# * **ROUTEID**
#     * A LINEID has multiple ROUTEID
#     * A LINEID may / may not have trips with both INBOUND-going(1)/OUTBOUND-returning(2) direction
#
# ### Source of Truth gathered in this notebook
# * **LINEID**
#     * **For a LINEID; ROUTEIDs and TRIPIDs used for DIFFERENT DIRECTION are MUTUALLY EXCLUSIVE**
# * **ROUTEID**
#     * **THOUGH 2 ROUTEIDs FOR A LINEID ARE HAVING SAME DIRECTION; STOPPOINTIDs VISITED ARE DIFFERENT**
#     * **FOR A SINGLE ROUTEID; STOPS VISITED DURING DIFFERENT TRIPS ARE DIFEENRENT**
#     * **AS ROUTEIDs ARE NOT KNOWN TO USER _AND_ ROUTEIDs ARE NOT TIMEBOUND; IT IS NOT POSSIBLE TO TRAIN ML MODEL USING ALL ROUTEIDs**

# %% [markdown]
# ## Check nature of data for a random LINEID
# **Jan_trips_MERGED.csv contains leavetimes Data for January 2018 merged with trips data**

# %%
import pandas as pd

# %%
df_Jan_trips = pd.read_csv("../DB/ML/Jan_trips_MERGED.csv")

# %%
df_Jan_trips['DAYOFSERVICE'] = pd.to_datetime(df_Jan_trips['DAYOFSERVICE'])
df_Jan_trips['TRIPID'] = pd.to_numeric(df_Jan_trips['TRIPID'], downcast='integer', errors='coerce')
df_Jan_trips['PROGRNUMBER'] = pd.to_numeric(df_Jan_trips['PROGRNUMBER'], downcast='integer', errors='coerce')
df_Jan_trips['STOPPOINTID'] = pd.to_numeric(df_Jan_trips['STOPPOINTID'], downcast='integer', errors='coerce')
df_Jan_trips['PLANNEDTIME_ARR'] = pd.to_numeric(df_Jan_trips['PLANNEDTIME_ARR'], downcast='integer', errors='coerce')
df_Jan_trips['PLANNEDTIME_DEP'] = pd.to_numeric(df_Jan_trips['PLANNEDTIME_DEP'], downcast='integer', errors='coerce')
df_Jan_trips['ACTUALTIME_ARR'] = pd.to_numeric(df_Jan_trips['ACTUALTIME_ARR'], downcast='integer', errors='coerce')
df_Jan_trips['ACTUALTIME_DEP'] = pd.to_numeric(df_Jan_trips['ACTUALTIME_DEP'], downcast='integer', errors='coerce')
df_Jan_trips['LINEID'] = df_Jan_trips['LINEID'].astype('str')
df_Jan_trips['ROUTEID'] = df_Jan_trips['ROUTEID'].astype('str')
df_Jan_trips['DIRECTION'] = pd.to_numeric(df_Jan_trips['DIRECTION'], downcast='integer', errors='coerce')

# %% [markdown]
# ### Object types and valid entries

# %%
print(df_Jan_trips.info(null_counts = True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10525004 entries, 0 to 10525003
# Data columns (total 11 columns):
#  #   Column           Non-Null Count     Dtype
# ---  ------           --------------     -----
#  0   DAYOFSERVICE     10525004 non-null  datetime64[ns]
#  1   TRIPID           10525004 non-null  int32
#  2   PROGRNUMBER      10525004 non-null  int8
#  3   STOPPOINTID      10525004 non-null  int16
#  4   PLANNEDTIME_ARR  10525004 non-null  int32
#  5   PLANNEDTIME_DEP  10525004 non-null  int32
#  6   ACTUALTIME_ARR   10525004 non-null  int32
#  7   ACTUALTIME_DEP   10525004 non-null  int32
#  8   LINEID           10525004 non-null  object
#  9   DIRECTION        10525004 non-null  int8
#  10  ROUTEID          10525004 non-null  object
# dtypes: datetime64[ns](1), int16(1), int32(5), int8(2), object(2)
# memory usage: 481.8+ MB
# None

# %% [markdown]
# ### Nature of data

# %%
df_Jan_trips.head(100)
# Out:
#    DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0    2018-01-01  5958355            3         1172            23799
# 1    2018-01-01  5958355            4         1173            23860
# 2    2018-01-01  5958355            5         1174            23937
# 3    2018-01-01  5958355            6         1175            24048
# 4    2018-01-01  5958355            7           15            24130
# ..          ...      ...          ...          ...              ...
# 95   2018-01-01  5958088           47         3958            27943
# 96   2018-01-01  5958088           48         3959            27990
# 97   2018-01-01  5958088           49         3960            28024
# 98   2018-01-01  5958088           50         3961            28058
# 99   2018-01-01  5958088           51         3962            28114
#
#     PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION ROUTEID
# 0             23799           23863           23863     41          1    41_3
# 1             23860           23934           24072     41          1    41_3
# 2             23937           24114           24140     41          1    41_3
# 3             24048           24180           24192     41          1    41_3
# 4             24130           24227           24257     41          1    41_3
# ..              ...             ...             ...    ...        ...     ...
# 95            27943           28473           28473     66          1   66_11
# 96            27990           28508           28508     66          1   66_11
# 97            28024           28534           28534     66          1   66_11
# 98            28058           28551           28562     66          1   66_11
# 99            28114           28600           28610     66          1   66_11
#
# [100 rows x 11 columns]

# %% [markdown]
# ### Unique entries

# %%
df_Jan_trips.nunique()
# Out:
# DAYOFSERVICE          31
# TRIPID             76453
# PROGRNUMBER          103
# STOPPOINTID         4714
# PLANNEDTIME_ARR    68859
# PLANNEDTIME_DEP    68859
# ACTUALTIME_ARR     71982
# ACTUALTIME_DEP     71965
# LINEID               126
# DIRECTION              2
# ROUTEID              498
# dtype: int64

# %% [markdown]
# ### Take samples for a random LINEID 41

# %%
df_Jan_trips_41 = df_Jan_trips.loc[(df_Jan_trips['LINEID'] == '41')]

# %%
df_Jan_trips_41
# Out:
#          DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0          2018-01-01  5958355            3         1172            23799
# 1          2018-01-01  5958355            4         1173            23860
# 2          2018-01-01  5958355            5         1174            23937
# 3          2018-01-01  5958355            6         1175            24048
# 4          2018-01-01  5958355            7           15            24130
# ...               ...      ...          ...          ...              ...
# 10523248   2018-01-31  6230682           51           48            86831
# 10523249   2018-01-31  6230682           52           49            86890
# 10523250   2018-01-31  6230682           53           51            86947
# 10523251   2018-01-31  6230682           54           52            86978
# 10523252   2018-01-31  6230682           55          277            87131
#
#           PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 0                   23799           23863           23863     41          1
# 1                   23860           23934           24072     41          1
# 2                   23937           24114           24140     41          1
# 3                   24048           24180           24192     41          1
# 4                   24130           24227           24257     41          1
# ...                   ...             ...             ...    ...        ...
# 10523248            86831           86772           86772     41          2
# 10523249            86890           86797           86811     41          2
# 10523250            86947           86853           86853     41          2
# 10523251            86978           86869           86869     41          2
# 10523252            87131           87019           87019     41          2
#
#          ROUTEID
# 0           41_3
# 1           41_3
# 2           41_3
# 3           41_3
# 4           41_3
# ...          ...
# 10523248    41_7
# 10523249    41_7
# 10523250    41_7
# 10523251    41_7
# 10523252    41_7
#
# [156082 rows x 11 columns]

# %% [markdown]
# ### Object types and valid entries

# %%
df_Jan_trips_41.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156082 entries, 0 to 10523252
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   DAYOFSERVICE     156082 non-null  datetime64[ns]
#  1   TRIPID           156082 non-null  int32
#  2   PROGRNUMBER      156082 non-null  int8
#  3   STOPPOINTID      156082 non-null  int16
#  4   PLANNEDTIME_ARR  156082 non-null  int32
#  5   PLANNEDTIME_DEP  156082 non-null  int32
#  6   ACTUALTIME_ARR   156082 non-null  int32
#  7   ACTUALTIME_DEP   156082 non-null  int32
#  8   LINEID           156082 non-null  object
#  9   DIRECTION        156082 non-null  int8
#  10  ROUTEID          156082 non-null  object
# dtypes: datetime64[ns](1), int16(1), int32(5), int8(2), object(2)
# memory usage: 8.3+ MB

# %% [markdown]
# ### Varify if ROUTEIDs and associated TRIPIDs for different DIRECTION for a LINEID are different

# %% [markdown]
# #### Direction 1

# %%
df_41_DIR1 = df_Jan_trips_41.loc[(df_Jan_trips_41['DIRECTION'] == 1)].sort_values(by = 'PROGRNUMBER')

# %%
df_41_DIR1.head()
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 6270489   2018-01-19  6115935            1          288            43800
# 4283850   2018-01-13  6093453            1          288            58800
# 9662196   2018-01-29  6238592            1          288            63000
# 2334981   2018-01-08  6093329            1          288            41100
# 9997660   2018-01-30  6234994            1          288            57000
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 6270489            43800           43803           43803     41          1
# 4283850            58800           59684           59684     41          1
# 9662196            63000           63055           63055     41          1
# 2334981            41100           41114           41114     41          1
# 9997660            57000           57100           57100     41          1
#
#         ROUTEID
# 6270489    41_3
# 4283850    41_3
# 9662196    41_3
# 2334981    41_3
# 9997660    41_3

# %% [markdown]
# #### Take unique values into dictionary

# %%
uniques = {}
for col in df_41_DIR1.columns:
    uniques[col] = df_41_DIR1[col].unique()

# %% [markdown]
# ##### Direction 1 ROUTES

# %%
LINE_41_DIR1_Routes = uniques['ROUTEID']

# %%
LINE_41_DIR1_Routes
# Out:
# array(['41_3', '41_21', '41_6', '41_20', '41_4', '41_5'], dtype=object)

# %% [markdown]
# ##### Direction 1 TRIPS

# %%
LINE_41_DIR1_Trips = uniques['TRIPID']

# %%
LINE_41_DIR1_Trips[:10]
# Out:
# array([6115935, 6093453, 6238592, 6093329, 6234994, 5956158, 6094587,
#        6109496, 6220913, 6094016], dtype=int32)

# %% [markdown]
# <br>

# %% [markdown]
# #### Direction 2

# %%
df_41_DIR2 = df_Jan_trips_41.loc[(df_Jan_trips_41['DIRECTION'] == 2)].sort_values(by = 'PROGRNUMBER')

# %%
df_41_DIR2.head()
# Out:
#          DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 181        2018-01-01  5965379            1         7347            26100
# 1981564    2018-01-06  5960063            1         4843            79200
# 7686543    2018-01-23  6215768            1         4843            68400
# 10422730   2018-01-31  6242687            1         4843            63300
# 4945366    2018-01-15  6108726            1         4843            75600
#
#           PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 181                 26100           26251           26251     41          2
# 1981564             79200           79228           79228     41          2
# 7686543             68400           68398           68398     41          2
# 10422730            63300           63499           63499     41          2
# 4945366             75600           75518           75518     41          2
#
#          ROUTEID
# 181        41_10
# 1981564     41_7
# 7686543     41_7
# 10422730    41_7
# 4945366     41_7

# %% [markdown]
# #### Take unique values into dictionary

# %%
uniques = {}
for col in df_41_DIR2.columns:
    uniques[col] = df_41_DIR2[col].unique()

# %% [markdown]
# ##### Direction 2 ROUTES

# %%
LINE_41_DIR2_Routes = uniques['ROUTEID']

# %%
LINE_41_DIR2_Routes
# Out:
# array(['41_10', '41_7', '41_9', '41_8'], dtype=object)

# %% [markdown]
# ##### Direction 2 TRIPS

# %%
LINE_41_DIR2_Trips = uniques['TRIPID']

# %%
LINE_41_DIR2_Trips[:10]
# Out:
# array([5965379, 5960063, 6215768, 6242687, 6108726, 6240229, 6089548,
#        5962111, 6218879, 6098757], dtype=int32)

# %% [markdown]
# <br>

# %% [markdown]
# #### Confirm mutual exclusion for TRIPIDs and ROUTEIDs for different directions

# %%
print("Common ROUTEIDs between LINE 43 : Direction 1 & 2 ",set(LINE_41_DIR1_Routes).intersection(LINE_41_DIR2_Routes))
# Out:
# Common ROUTEIDs between LINE 43 : Direction 1 & 2  set()

# %%
print("Common TRIPIDs between LINE 43 : Direction 1 & 2 ",set(LINE_41_DIR1_Trips).intersection(LINE_41_DIR2_Trips))
# Out:
# Common TRIPIDs between LINE 43 : Direction 1 & 2  set()

# %% [markdown]
# <br>
#
# **As observed, intersection for TRIIDs and ROUTEIDs used for INBOUND and OUTBOUND directions are totoally different and unshared.**<br><br>
# **$HENCE,\ For\ a\ LINEID;\ ROUTEIDs\ and\ TRIPIDs\ used\ for\ DIFFERENT\ DIRECTION\ are\ mutually\ exclusive$**
#
# <br>
# <br>

# %% [markdown]
# ### Check if STOPIDs visited by different ROUTEIDs for a LINEID are different

# %% [markdown]
# #### Take unique values into dictionary

# %%
uniques = {}
for col in df_Jan_trips_41.columns:
    uniques[col] = df_Jan_trips_41[col].unique()

# %%
uniques['ROUTEID']
# Out:
# array(['41_3', '41_10', '41_7', '41_8', '41_5', '41_4', '41_6', '41_9',
#        '41_20', '41_21'], dtype=object)

# %%
uniques['DAYOFSERVICE']
# Out:
# array(['2018-01-01T00:00:00.000000000', '2018-01-02T00:00:00.000000000',
#        '2018-01-03T00:00:00.000000000', '2018-01-04T00:00:00.000000000',
#        '2018-01-05T00:00:00.000000000', '2018-01-06T00:00:00.000000000',
#        '2018-01-07T00:00:00.000000000', '2018-01-08T00:00:00.000000000',
#        '2018-01-09T00:00:00.000000000', '2018-01-10T00:00:00.000000000',
#        '2018-01-11T00:00:00.000000000', '2018-01-12T00:00:00.000000000',
#        '2018-01-13T00:00:00.000000000', '2018-01-14T00:00:00.000000000',
#        '2018-01-15T00:00:00.000000000', '2018-01-16T00:00:00.000000000',
#        '2018-01-17T00:00:00.000000000', '2018-01-18T00:00:00.000000000',
#        '2018-01-19T00:00:00.000000000', '2018-01-20T00:00:00.000000000',
#        '2018-01-21T00:00:00.000000000', '2018-01-22T00:00:00.000000000',
#        '2018-01-23T00:00:00.000000000', '2018-01-24T00:00:00.000000000',
#        '2018-01-25T00:00:00.000000000', '2018-01-26T00:00:00.000000000',
#        '2018-01-27T00:00:00.000000000', '2018-01-28T00:00:00.000000000',
#        '2018-01-29T00:00:00.000000000', '2018-01-30T00:00:00.000000000',
#        '2018-01-31T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
# #### Check random entries for ROUTEID

# %%
df_Jan_trips_41.loc[(df_Jan_trips_41['ROUTEID'] == '41_3')].sort_values(by = 'PROGRNUMBER').head()
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7383709   2018-01-23  6216050            1          288            21600
# 8807333   2018-01-26  6212621            1          288            66300
# 4983921   2018-01-16  6115930            1          288            19800
# 2931133   2018-01-09  6098110            1          288            76500
# 1783885   2018-01-06  5972065            1          288            38400
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 7383709            21600           21581           21581     41          1
# 8807333            66300           66514           66514     41          1
# 4983921            19800           19783           19783     41          1
# 2931133            76500           76500           76500     41          1
# 1783885            38400           38357           38357     41          1
#
#         ROUTEID
# 7383709    41_3
# 8807333    41_3
# 4983921    41_3
# 2931133    41_3
# 1783885    41_3

# %%
df_Jan_trips_41.loc[(df_Jan_trips_41['ROUTEID'] == '41_20')].sort_values(by = 'PROGRNUMBER').head()
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1883383   2018-01-06  5955994            1         1174            57600
# 9064766   2018-01-27  6225628            1         1174            57600
# 6677252   2018-01-20  6121831            1         1174            57600
# 4277167   2018-01-13  6097348            1         1174            57600
# 1883384   2018-01-06  5955994            2         1175            57703
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 1883383            57600           57622           57622     41          1
# 9064766            57600           57757           57757     41          1
# 6677252            57600           57552           57552     41          1
# 4277167            57600           57614           57614     41          1
# 1883384            57703           57650           57650     41          1
#
#         ROUTEID
# 1883383   41_20
# 9064766   41_20
# 6677252   41_20
# 4277167   41_20
# 1883384   41_20

# %% [markdown]
# **IT IS EVIDENT FROM ABOVE SAMPLES THAT:**<BR>
# **THERE IS NO REALTION BETWEEN TIME OF OPERATION AND ROUTEID SELECTED**
# <BR>
# <BR>
# <BR>

# %% [markdown]
# #### Choose a combination of keys for ROUTEID 41_3

# %%
df_41_3_sample = df_Jan_trips_41.loc[(df_Jan_trips_41['LINEID'] == '41') & 
                                       (df_Jan_trips_41['ROUTEID'] == '41_3') &
                                       (df_Jan_trips_41['DAYOFSERVICE'] == '2018-01-08 00:00:00') &
                                       (df_Jan_trips_41['TRIPID'] == 6099945) &                                       
                                       (df_Jan_trips_41['DIRECTION'] == 1)
                                      ].sort_values(by = 'PROGRNUMBER')
df_41_3_sample.head()
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 2358345   2018-01-08  6099945            1          288            45000
# 2358346   2018-01-08  6099945            2         1171            45067
# 2358347   2018-01-08  6099945            3         1172            45118
# 2358348   2018-01-08  6099945            4         1173            45191
# 2358349   2018-01-08  6099945            5         1174            45285
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 2358345            45000           44996           44996     41          1
# 2358346            45067           45039           45039     41          1
# 2358347            45118           45055           45055     41          1
# 2358348            45191           45134           45148     41          1
# 2358349            45285           45182           45182     41          1
#
#         ROUTEID
# 2358345    41_3
# 2358346    41_3
# 2358347    41_3
# 2358348    41_3
# 2358349    41_3

# %% [markdown]
# #### Choose a combination of keys for ROUTEID 41_20

# %%
df_41_20_sample = df_Jan_trips_41.loc[(df_Jan_trips_41['LINEID'] == '41') &
                                        (df_Jan_trips_41['ROUTEID'] == '41_20') &
                                        (df_Jan_trips_41['TRIPID'] == 5955994) &
                                        (df_Jan_trips_41['DAYOFSERVICE'] == '2018-01-06 00:00:00') &
                                        (df_Jan_trips_41['DIRECTION'] == 1)
                                       ].sort_values(by = 'PROGRNUMBER')
df_41_20_sample.head()
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 1883383   2018-01-06  5955994            1         1174            57600
# 1883384   2018-01-06  5955994            2         1175            57703
# 1883385   2018-01-06  5955994            3           15            57780
# 1883386   2018-01-06  5955994            4           17            57900
# 1883387   2018-01-06  5955994            5           18            58001
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 1883383            57600           57622           57622     41          1
# 1883384            57703           57650           57650     41          1
# 1883385            57780           57716           57750     41          1
# 1883386            57900           57798           57798     41          1
# 1883387            58001           57865           57865     41          1
#
#         ROUTEID
# 1883383   41_20
# 1883384   41_20
# 1883385   41_20
# 1883386   41_20
# 1883387   41_20

# %% [markdown]
# #### View sets of STOPPOINTIDs visited for particular  ROUTEIDs

# %%
print("ROUTE 41_3",set(df_41_3_sample['STOPPOINTID']),"\n")
print("ROUTE 41_20",set(df_41_20_sample['STOPPOINTID']))
# Out:
# ROUTE 41_3 {15, 17, 18, 1171, 1172, 1173, 1174, 1175, 19, 21, 3864, 3865, 3669, 288, 6054, 4910, 4911, 4912, 4913, 7602, 4914, 7348, 4915, 5076, 203, 204, 205, 5073, 5074, 5075, 1620, 85, 1622, 1623, 1624, 1625, 1626, 1627, 220, 1628, 1629, 1630, 3671, 3672, 3674, 3675, 3676, 3679, 3682, 4330, 4957}
#
# ROUTE 41_20 {15, 17, 18, 19, 21, 1174, 1175, 3864, 3865, 3669, 4910, 4911, 4912, 4913, 7602, 4914, 7348, 4915, 5076, 203, 204, 205, 5075, 1620, 85, 1622, 1623, 1624, 1625, 1626, 1627, 220, 1628, 1629, 1630, 3679, 4957, 3682}

# %% [markdown]
# **OBSERVATIONS FROM ABOVE SETS**<BR>
# * **EVEN FOR ROUTEIDs HAVING SAME DIRECTION (DIRECTION = 1); STOPPOINTIDs VISITED ARE DIFFERENT**

# %% [markdown]
# ### Check if a TIMETABLE exists for ROUTEIDs
# * **If a specific ROUTEID is followed during specific Time slot; then such dynamic variations can be shown to users depending on time of travel**
# * **Following cells try to find if planned aarival time for different ROUTEIDs are following stringent TIMETABLE or NOT**

# %% [markdown]
# #### Set of arrival times followed for each ROUTEID of Line 41
# * **A ROUTEID in a LINE can be served multiple times in a day**
# * **It is evident that same TRIPIDs are shared across days**
# * **Hence, PLANNEDTIME_ARR of first PROGRNUMBER are listed and compared for each ROUTEID. This operation is done for each TRIPID in each DAYOFSERVICE**

# %%
import collections
# For each day of service when LINEID 41 operated; find set of planned arrival time during each TRIP 
# Each TRIP sereved a different ROUTEID

# default dictionary opens a dictionary where keys are not initated; and values can be appended
planned_arr_dict = collections.defaultdict(list)

for day in list(df_Jan_trips_41['DAYOFSERVICE'].unique()):
    
    df_Jan_trips_41_dayOfService = df_Jan_trips_41.loc[(df_Jan_trips_41['DAYOFSERVICE'] == day)][['TRIPID','ROUTEID','PROGRNUMBER','PLANNEDTIME_ARR']]
    trip_id = list(df_Jan_trips_41_dayOfService['TRIPID'].unique()) 
    
    for trip in list(trip_id):
        
        df_Jan_trips_41_trip = df_Jan_trips_41_dayOfService.loc[\
            (df_Jan_trips_41_dayOfService['TRIPID'] == trip)].sort_values(by = 'PROGRNUMBER')\
            [['ROUTEID','PROGRNUMBER','PLANNEDTIME_ARR']]

        # Ensure that for a TRIPID, single ROUTEID Exists
        if df_Jan_trips_41_trip['ROUTEID'].nunique() == 1:
            route_id = list(df_Jan_trips_41_trip['ROUTEID'].unique())[0]
            planned_arr_dict[route_id].append(df_Jan_trips_41_trip.sort_values(by = 'PROGRNUMBER')['PLANNEDTIME_ARR'].iloc[0])

    for route in planned_arr_dict.keys():
        planned_arr_dict[route] = sorted(list(set(planned_arr_dict[route])) )

# %%
for (route_id, arrival_times) in planned_arr_dict.items():
    print("set of PLANNEDTIME_ARR for ROUTEID ",route_id,":", arrival_times,"\n")
# Out:
# set of PLANNEDTIME_ARR for ROUTEID  41_3 : [18000, 18076, 18123, 18136, 18183, 18203, 19800, 19920, 19923, 19936, 21600, 21723, 21803, 22200, 22317, 22330, 23700, 23799, 23836, 23860, 24600, 25200, 25280, 25833, 26100, 27000, 27130, 27300, 27399, 27460, 27600, 28320, 28800, 29400, 29700, 30600, 31200, 31360, 32100, 32400, 33600, 34200, 35453, 36000, 37200, 37800, 38400, 39600, 39900, 40200, 40702, 40800, 41100, 42300, 42600, 43200, 43318, 43389, 43500, 43800, 43971, 44700, 45000, 45600, 45900, 46074, 46200, 46260, 46267, 46370, 46372, 46391, 46500, 46800, 47100, 47101, 47400, 47499, 47517, 48000, 48600, 49200, 49800, 50400, 50589, 51000, 51391, 51600, 52200, 52800, 53400, 53518, 53700, 54000, 54107, 54300, 54455, 54600, 55200, 55800, 56400, 57000, 57600, 57757, 57783, 57900, 57969, 58096, 58117, 58800, 58957, 59353, 60000, 60300, 60739, 61200, 61500, 61726, 61800, 61980, 63000, 64200, 64313, 64355, 64383, 64800, 65400, 66000, 66300, 66612, 67200, 67800, 68400, 68700, 69300, 70200, 71100, 72000, 72900, 73051, 73800, 74700, 75600, 75782, 76500, 77400, 78300, 79200, 80100, 81000, 81900, 82037, 82800]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_10 : [26100, 44400, 44545, 44633, 44675, 44706]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_7 : [21600, 22500, 22593, 22595, 22626, 23100, 23700, 23793, 23795, 24118, 24300, 24347, 24393, 24395, 24399, 24400, 24426, 24429, 25200, 25326, 25618, 26100, 26150, 26193, 26195, 26518, 26921, 27000, 28800, 30000, 30600, 31500, 32400, 32500, 32637, 33000, 33600, 34200, 34800, 35400, 35700, 36000, 36900, 37200, 37800, 38400, 38490, 38522, 38700, 39600, 39900, 40200, 40800, 41400, 42000, 42900, 43200, 43800, 44100, 45000, 45093, 45094, 45300, 45900, 46200, 47100, 47400, 47634, 48000, 48300, 48600, 49200, 49500, 49800, 50100, 50579, 50585, 50700, 51000, 51600, 51900, 52200, 53100, 53400, 54120, 54300, 54600, 55200, 55500, 55800, 56400, 56486, 56700, 56739, 56815, 57000, 57300, 58200, 58500, 59400, 59700, 60000, 60600, 60900, 60930, 61429, 61508, 61800, 62100, 62160, 62400, 62881, 62966, 63000, 63003, 63300, 63386, 63600, 63951, 64200, 64500, 64800, 65044, 65400, 66000, 66600, 66900, 67200, 68100, 68400, 68440, 69600, 70200, 71400, 72000, 72300, 72900, 73800, 74700, 75600, 76500, 76519, 77400, 78300, 79200, 80100, 80700, 81000, 81250, 81900, 82800, 83700, 84300, 84600]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_8 : [25500, 27000, 27147, 27150, 27395, 27632, 28018, 28200, 29100]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_5 : [27000]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_4 : [28200]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_6 : [28500]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_9 : [62400]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_20 : [57600]
#
# set of PLANNEDTIME_ARR for ROUTEID  41_21 : [84600]

# %% [markdown]
# #### INTERSECTION BETWEEN ROUTE TIMINGS

# %% [markdown]
# ##### Direction = 1

# %%
set(planned_arr_dict['41_3']).intersection(planned_arr_dict['41_5'])
# Out:
# {27000}

# %% [markdown]
# ##### Direction = 2

# %%
set(planned_arr_dict['41_7']).intersection(planned_arr_dict['41_10'])
# Out:
# {26100}

# %% [markdown]
# **OBSERVATIONS**
# * **IT IS CLEAR THAT ROUTE 41_3 [DIRECTION = 1] AND 41_7 [DIRECTION = 2] ARE FREQUENT ROUTES**
# * **IT IS EVIDENT THAT ROUTES DO NOT HAVE CLEAR DISTINCT TIMES**
#     * EXAMPLE: ROUTE 41_7 AND 41-10 ARE BOTH [DIRECTION=2] ROUTES AND HAVE SAM SCHEDULED DEPARTURES<br>
#
# **AS ROUTEIDs ARE NOT KNOWN TO USER $\Large \&$ ROUTEIDs ARE NOT TIMEBOUND; IT IS NOT POSSIBLE TO TRAIN ML MODEL USING ALL ROUTEIDs**

# %% [markdown]
# ### Check distribution for each ROUTEID of each LINEID
# **From above evaluation; we do not find definite titmetable is observed to operate a specific ROUTEID**
# * **Hence, we need to consider data from specific ROUTEID only and drop the rest**
# * **Before taking the step, we should ensure that:**
#     * **There exists a dominant ROUTEID for either direction of LINEID**

# %%
# plot counts of entries for ROUTEID of a particular LINEID

df_dominant_route = pd.DataFrame(columns=["LINEID","DOMINANT_ROUTEID","DIRECTION"])
with PdfPages('LINEID_Route_counts.pdf') as pp:
    for Line in list(df_Jan_trips.LINEID.unique()):
        
        # dataframe dominant_route is used to record dominant route for each LINEID
        df_line = df_Jan_trips.loc[df_Jan_trips["LINEID"] == Line]
        try:
            dom_route_D1 = df_line[(df_line["DIRECTION"] == 1)]["ROUTEID"].value_counts(sort=True).keys()[0]
            df_dominant_route.loc[len(df_dominant_route)] = [Line,dom_route_D1,1]
        except:
            print("error in line",Line,"direction 2")
        
        try:
            dom_route_D2 = df_line[(df_line["DIRECTION"] == 2)]["ROUTEID"].value_counts(sort=True).keys()[0]            
            df_dominant_route.loc[len(df_dominant_route)] = [Line,dom_route_D2,2]
        except:
            print("error in line",Line,"direction 2")
            
        plt.figure()
        sns.catplot(x="ROUTEID",col="DIRECTION",kind="count",palette=sns.color_palette(['orange', 'black']), \
                data=df_line)
        pp.savefig()
# Out:
# error in line 41A direction 2
# error in line 77X direction 2
# error in line 51X direction 2
# error in line 46E direction 2
# error in line 118 direction 2
# error in line 68X direction 2

# %%
df_dominant_route.to_csv('../DB/dominant_route.csv', index=False)

# %% [markdown]
# **AS SHOWN, MAJORITY OF LINEID HAS A SINGLE DOMINANT ROUTEID IN EITHER DIRECTION**
# * **Thus, non dominant ROUTEIDs for them can be safely dropped**
# * **Even for LINEIDs having multiple ROUTEIDs with considerable observation points; same strategy is observed**

# %% [markdown]
# ### Varify if STOPIDs visited for a ROUTEID for a LINEID in different trips are different thoughout database

# %%
df_41_3 =  df_Jan_trips_41.loc[(df_Jan_trips_41['ROUTEID'] == '41_3')].sort_values(by = 'PROGRNUMBER')

# %%
df_41_3
# Out:
#          DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 7383709    2018-01-23  6216050            1          288            21600
# 8807333    2018-01-26  6212621            1          288            66300
# 4983921    2018-01-16  6115930            1          288            19800
# 2931133    2018-01-09  6098110            1          288            76500
# 1783885    2018-01-06  5972065            1          288            38400
# ...               ...      ...          ...          ...              ...
# 4535257    2018-01-14  6112919           51         4957            68636
# 10293070   2018-01-31  6231183           51         4957            47131
# 9438985    2018-01-29  6245143           51         4957            31490
# 4400804    2018-01-14  6109174           51         4957            26496
# 10512735   2018-01-31  6240440           51         4957            84336
#
#           PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 7383709             21600           21581           21581     41          1
# 8807333             66300           66514           66514     41          1
# 4983921             19800           19783           19783     41          1
# 2931133             76500           76500           76500     41          1
# 1783885             38400           38357           38357     41          1
# ...                   ...             ...             ...    ...        ...
# 4535257             68636           68737           68737     41          1
# 10293070            47131           47595           47595     41          1
# 9438985             31490           31762           31762     41          1
# 4400804             26496           26293           26293     41          1
# 10512735            84336           84129           84129     41          1
#
#          ROUTEID
# 7383709     41_3
# 8807333     41_3
# 4983921     41_3
# 2931133     41_3
# 1783885     41_3
# ...          ...
# 4535257     41_3
# 10293070    41_3
# 9438985     41_3
# 4400804     41_3
# 10512735    41_3
#
# [71010 rows x 11 columns]

# %% [markdown]
# #### Take unique values into dictionary

# %%
uniques = {}
for col in df_41_3.columns:
    uniques[col] = df_41_3[col].unique()

# %%
uniques['ROUTEID']
# Out:
# array(['41_3'], dtype=object)

# %% [markdown]
# ####  View DAYOFSERVICE  when ROUTE 41_3 was served

# %%
DAYOFSERVICE_41_3 = list(uniques['DAYOFSERVICE'])

# %%
print("Days of service: ",len(DAYOFSERVICE_41_3))
print("5 entries as example: ", DAYOFSERVICE_41_3[:5])
# Out:
# Days of service:  31
# 5 entries as example:  [numpy.datetime64('2018-01-23T00:00:00.000000000'), numpy.datetime64('2018-01-26T00:00:00.000000000'), numpy.datetime64('2018-01-16T00:00:00.000000000'), numpy.datetime64('2018-01-09T00:00:00.000000000'), numpy.datetime64('2018-01-06T00:00:00.000000000')]

# %% [markdown]
# ####  View TRIPIDs used to serve ROUTE 41_3

# %%
TRIPID_41_3 = list(uniques['TRIPID'])

# %%
print("No of TRIPIDs: ",len(TRIPID_41_3))
print("5 entries as example: ", TRIPID_41_3[:5])
# Out:
# No of TRIPIDs:  574
# 5 entries as example:  [6216050, 6212621, 6115930, 6098110, 5972065]

# %% [markdown]
# #### Make dictionary of variants of STOPPOINTIDs visited during each of the TRIP on Route 41_3
# * **To confirm that stops visited during trips on same ROUTEID may be different; STOPPOINTIDs are grouped for each TRIPID on each DAYOFSERVICE for ROUTEID 41_3 data**
# * **VARIATIONS AND FREQUENCY IS OBSERVED FOR THE OCCURANCES**

# %%
import collections

STOPS_trips_41_3 = {}
trip_dayOfService_41_3 = list(df_41_3.reset_index(drop=True).groupby(['DAYOFSERVICE','TRIPID'])['STOPPOINTID'].apply(tuple))
print("Number of trips made on Route 41_3: ", len(trip_dayOfService_41_3),"\n\n")

set_41_3_stopList = list(set(tuple(row) for row in trip_dayOfService_41_3))
print("Number of ruote variations available for Route 41_3: ", len(set_41_3_stopList),"\n\n")

for stopList in set_41_3_stopList:
    STOPS_trips_41_3[stopList] = trip_dayOfService_41_3.count(stopList)
    
STOPS_trips_41_3 = {k: v for k, v in sorted(STOPS_trips_41_3.items(), key=lambda item: item[1],reverse=True)}


for (x, y) in STOPS_trips_41_3.items():
    print("Variation of Stops visited during route 41_3: ",x,"\nNumber of occurance for this vaiant: ", y,"\n")
# Out:
# Number of trips made on Route 41_3:  1423
#
#
# Number of ruote variations available for Route 41_3:  59
#
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1254
#
# Variation of Stops visited during route 41_3:  (1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  45
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  35
#
# Variation of Stops visited during route 41_3:  (1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  8
#
# Variation of Stops visited during route 41_3:  (288,)
# Number of occurance for this vaiant:  7
#
# Variation of Stops visited during route 41_3:  (1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  6
#
# Variation of Stops visited during route 41_3:  (288, 4957)
# Number of occurance for this vaiant:  4
#
# Variation of Stops visited during route 41_3:  (288, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  3
#
# Variation of Stops visited during route 41_3:  (1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  3
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  2
#
# Variation of Stops visited during route 41_3:  (288, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (1173, 1174, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 6054, 4330)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 3672, 3674, 3675, 3679, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 1175, 15, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1
#
# Variation of Stops visited during route 41_3:  (288, 1171, 1172, 1173, 1174, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)
# Number of occurance for this vaiant:  1

# %%
print("Number of vairants available for Route 41_3: ", len(STOPS_trips_41_3),"\n\n")
print("Most frequented variant for ROUTE 41_3: \n",next(iter(STOPS_trips_41_3)))
# Out:
# Number of vairants available for Route 41_3:  59
#
#
# Most frequented variant for ROUTE 41_3:
#  (288, 1171, 1172, 1173, 1174, 1175, 15, 17, 18, 19, 21, 7602, 85, 203, 204, 205, 1620, 220, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 7348, 3669, 3671, 3672, 3674, 3675, 3676, 5073, 5074, 6054, 4330, 3679, 5075, 5076, 3682, 3864, 3865, 4910, 4911, 4912, 4913, 4914, 4915, 4957)

# %% [markdown]
# **OBSERVATIONS FROM ABOVE SETS**<BR>
# * **EVEN FOR A SINGLE ROUTE; STOPS VISITED DURING DIFFERENT TRIPS MAY VARY PARTIALLY**
#     * **Though for ROUTEID 41_3, more than 88% occurances [1254 out of total 1423] follow a single STOPOINTID sequence**

# %% [markdown]
# <br><br>

# %% [markdown]
# ### Drop insignificant ROUTEIDS
# **From above anlysis; We have obtained source of truth stating that:**
# * **For a LINEID; ROUTEIDs and TRIPIDs used for DIFFERENT DIRECTION are mutually exclusive**
# * **EVEN FOR ROUTEIDs HAVING SAME DIRECTION; STOPPOINTIDs VISITED ARE DIFFERENT**
# * **ROUTEIDs ARE NOT KNOWN TO USER & ROUTEIDs ARE NOT TIMEBOUND i.e. timetable DOES NOT exists to follow a ROUTEID**
# * **majority of data for a LINEID is tied with a particular ROUTEID**
#
# **Hence, we can safely drop data for insignificant ROUTEIDs**

# %%
df_dominant_route_list = pd.read_csv('../DB/dominant_route.csv')
dominant_route_list = list(df_dominant_route_list["DOMINANT_ROUTEID"])
df_Jan_trips_dom_Route = df_Jan_trips.loc[df_Jan_trips['ROUTEID'].isin(dominant_route_list)]

# %%
dominant_route_list
# Out:
# ['41_3',
#  '41_7',
#  '66_11',
#  '66_13',
#  '77A_29',
#  '77A_28',
#  '83_16',
#  '83_22',
#  '130_10',
#  '130_11',
#  '151_15',
#  '151_17',
#  '40_27',
#  '40_31',
#  '122_14',
#  '122_16',
#  '13_60',
#  '13_67',
#  '65_74',
#  '65_77',
#  '41C_78',
#  '41C_79',
#  '75_17',
#  '75_19',
#  '33_44',
#  '33_70',
#  '15_16',
#  '15_17',
#  '7A_85',
#  '7A_87',
#  '27A_4',
#  '27A_5',
#  '67_4',
#  '67_6',
#  '15B_60',
#  '15B_61',
#  '150_8',
#  '150_9',
#  '39A_40',
#  '39A_43',
#  '123_34',
#  '123_36',
#  '16_20',
#  '16_24',
#  '27_19',
#  '27_17',
#  '29A_14',
#  '29A_15',
#  '7_66',
#  '7_70',
#  '145_102',
#  '145_105',
#  '4_10',
#  '4_12',
#  '39_20',
#  '39_21',
#  '38_9',
#  '38_14',
#  '46A_74',
#  '46A_67',
#  '18_3',
#  '18_4',
#  '65B_65',
#  '65B_66',
#  '25A_273',
#  '25A_270',
#  '14_15',
#  '14_16',
#  '25B_274',
#  '25B_271',
#  '31_15',
#  '31_18',
#  '31A_25',
#  '31A_26',
#  '27B_23',
#  '27B_34',
#  '84_27',
#  '84_30',
#  '40D_102',
#  '40D_104',
#  '15A_83',
#  '15A_84',
#  '17A_15',
#  '17A_17',
#  '54A_11',
#  '54A_12',
#  '38A_20',
#  '38A_32',
#  '9_5',
#  '9_7',
#  '37_14',
#  '37_15',
#  '33B_56',
#  '33B_58',
#  '184_29',
#  '184_28',
#  '70_60',
#  '70_67',
#  '104_15',
#  '104_16',
#  '42_42',
#  '42_44',
#  '63_26',
#  '63_30',
#  '68_81',
#  '68_83',
#  '66A_34',
#  '66A_36',
#  '32_57',
#  '32_58',
#  '140_19',
#  '140_21',
#  '47_139',
#  '47_136',
#  '49_27',
#  '49_28',
#  '44_40',
#  '44_36',
#  '76_36',
#  '76_37',
#  '61_106',
#  '61_108',
#  '102_8',
#  '102_9',
#  '43_84',
#  '43_88',
#  '56A_31',
#  '56A_30',
#  '83A_17',
#  '83A_23',
#  '11_40',
#  '11_42',
#  '79_10',
#  '79_11',
#  '1_37',
#  '1_40',
#  '120_7',
#  '120_9',
#  '45A_60',
#  '45A_64',
#  '59_10',
#  '59_11',
#  '69_43',
#  '69_44',
#  '53_20',
#  '53_21',
#  '17_10',
#  '17_15',
#  '185_53',
#  '185_56',
#  '270_42',
#  '270_44',
#  '25_272',
#  '25_269',
#  '79A_27',
#  '79A_28',
#  '238_11',
#  '238_15',
#  '220_10',
#  '220_12',
#  '26_24',
#  '26_26',
#  '33A_22',
#  '33A_25',
#  '41B_52',
#  '41B_53',
#  '40B_63',
#  '40B_65',
#  '16C_29',
#  '16C_28',
#  '14C_17',
#  '14C_18',
#  '7D_120',
#  '7D_121',
#  '66B_55',
#  '66B_57',
#  '38B_40',
#  '38B_44',
#  '84A_1',
#  '84A_3',
#  '84X_57',
#  '84X_52',
#  '239_26',
#  '239_28',
#  '68A_86',
#  '68A_87',
#  '111_7',
#  '111_8',
#  '33X_46',
#  '33X_47',
#  '76A_28',
#  '76A_29',
#  '7B_91',
#  '7B_93',
#  '44B_60',
#  '44B_61',
#  '41A_22',
#  '67X_38',
#  '67X_41',
#  '236_9',
#  '236_10',
#  '31B_44',
#  '31B_46',
#  '39X_1',
#  '39X_2',
#  '66X_92',
#  '66X_96',
#  '114_5',
#  '114_6',
#  '32X_74',
#  '32X_76',
#  '70D_70',
#  '70D_71',
#  '77X_61',
#  '51X_63',
#  '142_10',
#  '142_12',
#  '25D_277',
#  '25D_275',
#  '51D_50',
#  '51D_47',
#  '69X_59',
#  '69X_60',
#  '42D_50',
#  '42D_51',
#  '27X_43',
#  '27X_42',
#  '25X_7',
#  '25X_5',
#  '46E_93',
#  '38D_68',
#  '38D_61',
#  '41X_116',
#  '41X_109',
#  '116_1',
#  '116_3',
#  '31D_50',
#  '31D_51',
#  '161_50',
#  '161_51',
#  '118_3',
#  '15D_62',
#  '15D_63',
#  '68X_88',
#  '33D_61',
#  '33D_62']

# %% [markdown]
# #### Object types and valid entries

# %%
df_Jan_trips_dom_Route.info(null_counts= True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9600545 entries, 0 to 10524716
# Data columns (total 11 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   DAYOFSERVICE     9600545 non-null  datetime64[ns]
#  1   TRIPID           9600545 non-null  int32
#  2   PROGRNUMBER      9600545 non-null  int8
#  3   STOPPOINTID      9600545 non-null  int16
#  4   PLANNEDTIME_ARR  9600545 non-null  int32
#  5   PLANNEDTIME_DEP  9600545 non-null  int32
#  6   ACTUALTIME_ARR   9600545 non-null  int32
#  7   ACTUALTIME_DEP   9600545 non-null  int32
#  8   LINEID           9600545 non-null  object
#  9   DIRECTION        9600545 non-null  int8
#  10  ROUTEID          9600545 non-null  object
# dtypes: datetime64[ns](1), int16(1), int32(5), int8(2), object(2)
# memory usage: 512.7+ MB

# %% [markdown]
# #### Unique entries

# %%
df_Jan_trips_dom_Route.nunique()
# Out:
# DAYOFSERVICE          31
# TRIPID             69359
# PROGRNUMBER          102
# STOPPOINTID         4602
# PLANNEDTIME_ARR    67749
# PLANNEDTIME_DEP    67749
# ACTUALTIME_ARR     70065
# ACTUALTIME_DEP     70063
# LINEID               126
# DIRECTION              2
# ROUTEID              246
# dtype: int64

# %% [markdown]
# $\Large Analysis\ of\ sample\ size\ after\ dropping\ data$
# * **COUNT OF ENTRIES FOR ORIGINAL DATA df_Jan_trips = $10525004$ | with count of ROUTEIDs = $498$**
# * **COUNT OF ENTRIES FOR ORIGINAL DATA AFTER OMMITING NON SIGNIFICANT ROUTEIDS = $9600545$ | with count of ROUTEIDs = $246$**
# * **AFTER DROPPING DATA FOR NON SIGNIFICANT ROUTEIDS [which are roughly $50\%$ of total ROUTEIDs]; WE ARE STILL LEFT WITH $\Large 91\%$ OF DATA (9600545 / 10525004 * 100)**
# <br>
#
# **THIS IS SIGNIFICANT SIZE OF DATA SIZE TO TRAIN ON; AS WE HAVE REDUCED CARDINALITY OF ROUTEID FEATURE BY $50\%$ LOOSING ONLY $9\%$ OF DATA**

# %% [markdown]
# #### Save data to csv

# %%
df_Jan_trips_dom_Route.to_csv("../DB/ML/imp_ROUTEID_Jan_trips_MERGED.csv",index=False)

# %% [markdown]
# ## Check nature of Arrival and departure times
# * [Documentation on Dublin Bus data](https://brightspace.ucd.ie/d2l/le/content/54595/viewContent/922112/View) defines
#     * PlannedTime_Arr : Planned arrival time at the stop point, in seconds
#     * PlannedTime_Dep: Planned departure time from the stop point, in seconds
#     * ActualTime_Arr: Actual arrival time at the stop point, in seconds
#     * ActualTime_Dep: Actual departure time from the stop point, in seconds
# * **Value in seconds** is **offset in seconds from 00:00:00 for particular date**
#
# **EXTENDED TIMES**<br>
# * FOR LATE NIGHT TRIPS WHICH TECHNICALLY SPAN OVER 2 DAYS; **EXTENDED TIMES** ARE USED<br>
# For example a trip starting at 23:30 of 1st ofApril and ending at 00:30 of the 2nd of April could have the last AVL data tracked at “24:30of 1st of April”. To express this “extended time” the interface requires the use of secondspast the beginning of the operation day. In our example the DayOfService is “01/04/2014”and the extended time is “88200” (= 24*60*60 + 30*6)

# %%
import pandas as pd

# %%
df_Jan_trips_dom_Route = pd.read_csv("../DB/ML/imp_ROUTEID_Jan_trips_MERGED.csv")

# %%
df_Jan_trips_dom_Route['DAYOFSERVICE'] = pd.to_datetime(df_Jan_trips_dom_Route['DAYOFSERVICE'])
df_Jan_trips_dom_Route['TRIPID'] = pd.to_numeric(df_Jan_trips_dom_Route['TRIPID'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['PROGRNUMBER'] = pd.to_numeric(df_Jan_trips_dom_Route['PROGRNUMBER'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['STOPPOINTID'] = pd.to_numeric(df_Jan_trips_dom_Route['STOPPOINTID'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['PLANNEDTIME_ARR'] = pd.to_numeric(df_Jan_trips_dom_Route['PLANNEDTIME_ARR'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['PLANNEDTIME_DEP'] = pd.to_numeric(df_Jan_trips_dom_Route['PLANNEDTIME_DEP'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['ACTUALTIME_ARR'] = pd.to_numeric(df_Jan_trips_dom_Route['ACTUALTIME_ARR'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['ACTUALTIME_DEP'] = pd.to_numeric(df_Jan_trips_dom_Route['ACTUALTIME_DEP'], downcast='integer', errors='coerce')
df_Jan_trips_dom_Route['LINEID'] = df_Jan_trips_dom_Route['LINEID'].astype('str')
df_Jan_trips_dom_Route['ROUTEID'] = df_Jan_trips_dom_Route['ROUTEID'].astype('str')
df_Jan_trips_dom_Route['DIRECTION'] = pd.to_numeric(df_Jan_trips_dom_Route['DIRECTION'], downcast='integer', errors='coerce')

# %%
df_Jan_trips_dom_Route.head()
# Out:
#   DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0   2018-01-01  5958355            3         1172            23799
# 1   2018-01-01  5958355            4         1173            23860
# 2   2018-01-01  5958355            5         1174            23937
# 3   2018-01-01  5958355            6         1175            24048
# 4   2018-01-01  5958355            7           15            24130
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION ROUTEID
# 0            23799           23863           23863     41          1    41_3
# 1            23860           23934           24072     41          1    41_3
# 2            23937           24114           24140     41          1    41_3
# 3            24048           24180           24192     41          1    41_3
# 4            24130           24227           24257     41          1    41_3

# %%
df_Jan_trips_dom_Route.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9600545 entries, 0 to 9600544
# Data columns (total 11 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   DAYOFSERVICE     9600545 non-null  datetime64[ns]
#  1   TRIPID           9600545 non-null  int32
#  2   PROGRNUMBER      9600545 non-null  int8
#  3   STOPPOINTID      9600545 non-null  int16
#  4   PLANNEDTIME_ARR  9600545 non-null  int32
#  5   PLANNEDTIME_DEP  9600545 non-null  int32
#  6   ACTUALTIME_ARR   9600545 non-null  int32
#  7   ACTUALTIME_DEP   9600545 non-null  int32
#  8   LINEID           9600545 non-null  object
#  9   DIRECTION        9600545 non-null  int8
#  10  ROUTEID          9600545 non-null  object
# dtypes: datetime64[ns](1), int16(1), int32(5), int8(2), object(2)
# memory usage: 439.5+ MB

# %% [markdown]
# ### Check Entries containing Exteded Time
# **All TIME feature entries greater than “86400” (=24*60*60) are extended time entries**

# %%
df_Jan_trips_dom_Route_extendedTime = df_Jan_trips_dom_Route.loc[(df_Jan_trips_dom_Route['PLANNEDTIME_ARR'] > 86400) |
                                             (df_Jan_trips_dom_Route['PLANNEDTIME_DEP'] > 86400) |
                                             (df_Jan_trips_dom_Route['ACTUALTIME_ARR'] > 86400) |
                                             (df_Jan_trips_dom_Route['ACTUALTIME_DEP'] > 86400)
                                            ]
df_Jan_trips_dom_Route_extendedTime.head()
# Out:
#        DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 168753   2018-01-01  5960398           83         1280            86202
# 168754   2018-01-01  5960398           84         6348            86257
# 168996   2018-01-01  5961860           71         2601            85882
# 168997   2018-01-01  5961860           72         4446            85931
# 168998   2018-01-01  5961860           73         2603            86002
#
#         PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 168753            86202           86443           86443     40          2
# 168754            86257           86565           86565     40          2
# 168996            85882           86439           86439     27          1
# 168997            85931           86471           86471     27          1
# 168998            86002           86513           86522     27          1
#
#        ROUTEID
# 168753   40_31
# 168754   40_31
# 168996   27_19
# 168997   27_19
# 168998   27_19

# %%
df_Jan_trips_dom_Route_extendedTime.nunique()
# Out:
# DAYOFSERVICE         31
# TRIPID              923
# PROGRNUMBER         102
# STOPPOINTID        1316
# PLANNEDTIME_ARR    2627
# PLANNEDTIME_DEP    2627
# ACTUALTIME_ARR     3222
# ACTUALTIME_DEP     3222
# LINEID               62
# DIRECTION             2
# ROUTEID              97
# dtype: int64

# %% [markdown]
# ### Check Entries where all TIME features are in extended format

# %%
df_Jan_trips_dom_Route_extendedTime_all = df_Jan_trips_dom_Route.loc[(df_Jan_trips_dom_Route['PLANNEDTIME_ARR'] > 86400) &
                                             (df_Jan_trips_dom_Route['PLANNEDTIME_DEP'] > 86400) &
                                             (df_Jan_trips_dom_Route['ACTUALTIME_ARR'] > 86400) &
                                             (df_Jan_trips_dom_Route['ACTUALTIME_DEP'] > 86400)
                                            ]
df_Jan_trips_dom_Route_extendedTime_all.head()
# Out:
#        DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 169006   2018-01-01  5961860           81         2621            86450
# 169007   2018-01-01  5961860           82         2622            86481
# 169008   2018-01-01  5961860           83         2623            86509
# 169009   2018-01-01  5961860           84         2624            86567
# 169010   2018-01-01  5961860           85         4441            86610
#
#         PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 169006            86450           87023           87036     27          1
# 169007            86481           87081           87081     27          1
# 169008            86509           87106           87121     27          1
# 169009            86567           87163           87163     27          1
# 169010            86610           87199           87207     27          1
#
#        ROUTEID
# 169006   27_19
# 169007   27_19
# 169008   27_19
# 169009   27_19
# 169010   27_19

# %%
df_Jan_trips_dom_Route_extendedTime_all.shape
# Out:
# (15489, 11)

# %%
df_Jan_trips_dom_Route_extendedTime_all.nunique()
# Out:
# DAYOFSERVICE         31
# TRIPID              648
# PROGRNUMBER         102
# STOPPOINTID         918
# PLANNEDTIME_ARR    1765
# PLANNEDTIME_DEP    1765
# ACTUALTIME_ARR     2372
# ACTUALTIME_DEP     2386
# LINEID               54
# DIRECTION             2
# ROUTEID              76
# dtype: int64

# %% [markdown]
# ### Entries where few of the TIME features is in Extended Time but not all

# %%
df_Jan_trips_dom_Route_extendedTime_few = df_Jan_trips_dom_Route_extendedTime[~ df_Jan_trips_dom_Route_extendedTime.isin(df_Jan_trips_dom_Route_extendedTime_all)].dropna()

# %%
df_Jan_trips_dom_Route_extendedTime_few.head()
# Out:
#        DAYOFSERVICE     TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 168753   2018-01-01  5960398.0         83.0       1280.0          86202.0
# 168754   2018-01-01  5960398.0         84.0       6348.0          86257.0
# 168996   2018-01-01  5961860.0         71.0       2601.0          85882.0
# 168997   2018-01-01  5961860.0         72.0       4446.0          85931.0
# 168998   2018-01-01  5961860.0         73.0       2603.0          86002.0
#
#         PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 168753          86202.0         86443.0         86443.0     40        2.0
# 168754          86257.0         86565.0         86565.0     40        2.0
# 168996          85882.0         86439.0         86439.0     27        1.0
# 168997          85931.0         86471.0         86471.0     27        1.0
# 168998          86002.0         86513.0         86522.0     27        1.0
#
#        ROUTEID
# 168753   40_31
# 168754   40_31
# 168996   27_19
# 168997   27_19
# 168998   27_19

# %%
df_Jan_trips_dom_Route_extendedTime_few.shape
# Out:
# (10009, 11)

# %%
df_Jan_trips_dom_Route_extendedTime_few.nunique()
# Out:
# DAYOFSERVICE         31
# TRIPID              883
# PROGRNUMBER          86
# STOPPOINTID        1126
# PLANNEDTIME_ARR    1444
# PLANNEDTIME_DEP    1444
# ACTUALTIME_ARR     1635
# ACTUALTIME_DEP     1641
# LINEID               62
# DIRECTION             2
# ROUTEID              97
# dtype: int64

# %% [markdown]
# ### Check if arrival time for buses are early/ late than planned time

# %%
df_Jan_trips_dom_Route.loc[df_Jan_trips_dom_Route['PLANNEDTIME_ARR'] > df_Jan_trips_dom_Route['ACTUALTIME_ARR']]
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 24        2018-01-01  5958355           27         1630            25279
# 25        2018-01-01  5958355           28         7348            25508
# 26        2018-01-01  5958355           29         3669            25615
# 27        2018-01-01  5958355           30         3671            25677
# 28        2018-01-01  5958355           31         3672            25708
# ...              ...      ...          ...          ...              ...
# 9600540   2018-01-31  6232035           16         3726            86812
# 9600541   2018-01-31  6232035           17         7039            86848
# 9600542   2018-01-31  6232035           18         7204            86890
# 9600543   2018-01-31  6232035           19         3728            86988
# 9600544   2018-01-31  6232035           20         3729            87009
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 24                 25279           25246           25257     41          1
# 25                 25508           25487           25537     41          1
# 26                 25615           25611           25622     41          1
# 27                 25677           25664           25679     41          1
# 28                 25708           25707           25707     41          1
# ...                  ...             ...             ...    ...        ...
# 9600540            86812           86671           86671    33B          1
# 9600541            86848           86685           86685    33B          1
# 9600542            86890           86722           86761    33B          1
# 9600543            86988           86836           86836    33B          1
# 9600544            87009           86844           86844    33B          1
#
#         ROUTEID
# 24         41_3
# 25         41_3
# 26         41_3
# 27         41_3
# 28         41_3
# ...         ...
# 9600540  33B_56
# 9600541  33B_56
# 9600542  33B_56
# 9600543  33B_56
# 9600544  33B_56
#
# [4249812 rows x 11 columns]

# %% [markdown]
# ### Check if departure time for buses are early/ late than planned time

# %%
df_Jan_trips_dom_Route.loc[df_Jan_trips_dom_Route['PLANNEDTIME_DEP'] > df_Jan_trips_dom_Route['ACTUALTIME_DEP']]
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 24        2018-01-01  5958355           27         1630            25279
# 28        2018-01-01  5958355           31         3672            25708
# 30        2018-01-01  5958355           33         3675            25822
# 33        2018-01-01  5958355           36         5074            25999
# 34        2018-01-01  5958355           37         6054            26030
# ...              ...      ...          ...          ...              ...
# 9600540   2018-01-31  6232035           16         3726            86812
# 9600541   2018-01-31  6232035           17         7039            86848
# 9600542   2018-01-31  6232035           18         7204            86890
# 9600543   2018-01-31  6232035           19         3728            86988
# 9600544   2018-01-31  6232035           20         3729            87009
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 24                 25279           25246           25257     41          1
# 28                 25708           25707           25707     41          1
# 30                 25822           25816           25816     41          1
# 33                 25999           25976           25987     41          1
# 34                 26030           26025           26025     41          1
# ...                  ...             ...             ...    ...        ...
# 9600540            86812           86671           86671    33B          1
# 9600541            86848           86685           86685    33B          1
# 9600542            86890           86722           86761    33B          1
# 9600543            86988           86836           86836    33B          1
# 9600544            87009           86844           86844    33B          1
#
#         ROUTEID
# 24         41_3
# 28         41_3
# 30         41_3
# 33         41_3
# 34         41_3
# ...         ...
# 9600540  33B_56
# 9600541  33B_56
# 9600542  33B_56
# 9600543  33B_56
# 9600544  33B_56
#
# [4044312 rows x 11 columns]

# %% [markdown]
# ### Plot early/ late arrival and departures

# %%
df_Jan_trips_dom_Route['Arrival_lateEarly'] = df_Jan_trips_dom_Route['PLANNEDTIME_ARR'].ge(df_Jan_trips_dom_Route['ACTUALTIME_ARR'])
df_Jan_trips_dom_Route['departure_lateEarly'] = df_Jan_trips_dom_Route['PLANNEDTIME_DEP'].ge(df_Jan_trips_dom_Route['ACTUALTIME_DEP'])

# %%
df_Jan_trips_dom_Route[df_Jan_trips_dom_Route['Arrival_lateEarly'] == True]
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 24        2018-01-01  5958355           27         1630            25279
# 25        2018-01-01  5958355           28         7348            25508
# 26        2018-01-01  5958355           29         3669            25615
# 27        2018-01-01  5958355           30         3671            25677
# 28        2018-01-01  5958355           31         3672            25708
# ...              ...      ...          ...          ...              ...
# 9600540   2018-01-31  6232035           16         3726            86812
# 9600541   2018-01-31  6232035           17         7039            86848
# 9600542   2018-01-31  6232035           18         7204            86890
# 9600543   2018-01-31  6232035           19         3728            86988
# 9600544   2018-01-31  6232035           20         3729            87009
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 24                 25279           25246           25257     41          1
# 25                 25508           25487           25537     41          1
# 26                 25615           25611           25622     41          1
# 27                 25677           25664           25679     41          1
# 28                 25708           25707           25707     41          1
# ...                  ...             ...             ...    ...        ...
# 9600540            86812           86671           86671    33B          1
# 9600541            86848           86685           86685    33B          1
# 9600542            86890           86722           86761    33B          1
# 9600543            86988           86836           86836    33B          1
# 9600544            87009           86844           86844    33B          1
#
#         ROUTEID  Arrival_lateEarly  departure_lateEarly
# 24         41_3               True                 True
# 25         41_3               True                False
# 26         41_3               True                False
# 27         41_3               True                False
# 28         41_3               True                 True
# ...         ...                ...                  ...
# 9600540  33B_56               True                 True
# 9600541  33B_56               True                 True
# 9600542  33B_56               True                 True
# 9600543  33B_56               True                 True
# 9600544  33B_56               True                 True
#
# [4270920 rows x 13 columns]

# %% [markdown]
# ### Check relation between planned arrival and departures

# %%
df_Jan_trips_dom_Route['planned_arr_dep_equality'] = df_Jan_trips_dom_Route['PLANNEDTIME_ARR'].eq(df_Jan_trips_dom_Route['PLANNEDTIME_DEP'])

# %%
df_Jan_trips_dom_Route[df_Jan_trips_dom_Route['planned_arr_dep_equality'] == True]
# Out:
#         DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  PLANNEDTIME_ARR  \
# 0         2018-01-01  5958355            3         1172            23799
# 1         2018-01-01  5958355            4         1173            23860
# 2         2018-01-01  5958355            5         1174            23937
# 3         2018-01-01  5958355            6         1175            24048
# 4         2018-01-01  5958355            7           15            24130
# ...              ...      ...          ...          ...              ...
# 9600540   2018-01-31  6232035           16         3726            86812
# 9600541   2018-01-31  6232035           17         7039            86848
# 9600542   2018-01-31  6232035           18         7204            86890
# 9600543   2018-01-31  6232035           19         3728            86988
# 9600544   2018-01-31  6232035           20         3729            87009
#
#          PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP LINEID  DIRECTION  \
# 0                  23799           23863           23863     41          1
# 1                  23860           23934           24072     41          1
# 2                  23937           24114           24140     41          1
# 3                  24048           24180           24192     41          1
# 4                  24130           24227           24257     41          1
# ...                  ...             ...             ...    ...        ...
# 9600540            86812           86671           86671    33B          1
# 9600541            86848           86685           86685    33B          1
# 9600542            86890           86722           86761    33B          1
# 9600543            86988           86836           86836    33B          1
# 9600544            87009           86844           86844    33B          1
#
#         ROUTEID  Arrival_lateEarly  departure_lateEarly  \
# 0          41_3              False                False
# 1          41_3              False                False
# 2          41_3              False                False
# 3          41_3              False                False
# 4          41_3              False                False
# ...         ...                ...                  ...
# 9600540  33B_56               True                 True
# 9600541  33B_56               True                 True
# 9600542  33B_56               True                 True
# 9600543  33B_56               True                 True
# 9600544  33B_56               True                 True
#
#          planned_arr_dep_equality
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# ...                           ...
# 9600540                      True
# 9600541                      True
# 9600542                      True
# 9600543                      True
# 9600544                      True
#
# [9600545 rows x 14 columns]

# %% [markdown]
# $\Large Analysis\ of\ sample\ size\ after\ dropping\ data$
# * **COUNT OF ENTRIES FOR ORIGINAL DATA IN df_Jan_trips_dom_Route : $9600545$**
# * **COUNT OF ENTRIES FOR DATA HAVING PLANNEDTIME_ARR == PLANNEDTIME_DEP : $9600545$**
# <br>
#
# $PLANNED\ ARRIVAL\ AND\ DEPARTURE\ TIMES\ ARE\ SAME\ FOR\ ALL\ ENTRIES.$
# $ HENCE\ "PLANNEDTIME\_DEP"\ CAN\ BE\ DROPPED$

# %%
df_Jan_trips_dom_Route.drop(["PLANNEDTIME_DEP"],inplace=True,axis=1)

# %% [markdown]
# #### Save data to csv

# %%
df_Jan_trips_dom_Route.to_csv("../DB/ML/imp_ROUTEID_Jan_trips_MERGED.csv",index=False)
